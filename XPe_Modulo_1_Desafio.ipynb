# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciairibarrem/Data-Science---Exercises/blob/main/XPe_Modulo_1_Desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Coletando Dados dos Estados**

# %%
import pandas as pd #bibliotca de leitura e tratamento de dataframes

# %%
#lendo arquivo
estados = pd.read_csv('estados_brasileiros.csv', sep = ';', encoding='latin-1')
estados.head()
# Out:
#    id_estado    estado sigla_estado    pais
# 0          1      Acre           ac  Brasil
# 1          2   Alagoas           al  Brasil
# 2          3     Amapá           ap  Brasil
# 3          4  Amazonas           am  Brasil
# 4          5     Bahia           ba  Brasil

# %% [markdown]
# Coletando Dados de Clientes

# %%
clientes = pd.read_excel('dados_clientes.xlsx')
clientes.head()
# Out:
#    id_cliente   peso  colesterol     genero  id_estado
# 0           1  102.0         111  Masculino         23
# 1           2  115.0         135  Masculino          7
# 2           3  115.0         136  Masculino          4
# 3           4  140.0         167   Feminino         24
# 4           5  130.0         158  Masculino         26

# %% [markdown]
# Coletando Dados das Idades dos Clientes

# %%
idade = pd.read_csv('idade_clientes.csv', sep =';', encoding='latin-1')
idade.head()
# Out:
#    id_cliente  idade
# 0           1     17
# 1           2     28
# 2           3     62
# 3           4     55
# 4           5     44

# %% [markdown]
# Preparação dos Dados: Limpar para análise

# %% [markdown]
# Analisando as variáveis da base de dados

# %%
#tipos de dados pra cada variável
clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  547 non-null    int64
#  1   peso        542 non-null    float64
#  2   colesterol  547 non-null    int64
#  3   genero      547 non-null    object
#  4   id_estado   547 non-null    int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 21.5+ KB

# %%
#estatística básica
clientes.describe()
# Out:
#        id_cliente        peso  colesterol   id_estado
# count   547.00000  542.000000  547.000000  547.000000
# mean    274.00000  143.440959  170.433272   13.833638
# std     158.04957   30.836868   39.147189    7.593117
# min       1.00000   95.000000  102.000000    1.000000
# 25%     137.50000  116.000000  136.000000    7.000000
# 50%     274.00000  140.000000  169.000000   13.000000
# 75%     410.50000  171.000000  208.000000   20.000000
# max     547.00000  203.000000  235.000000   27.000000

# %%
#tipos de dados pra cada variável
estados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_estado     27 non-null     int64
#  1   estado        27 non-null     object
#  2   sigla_estado  27 non-null     object
#  3   pais          25 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 992.0+ bytes

# %%
#tipos de dados pra cada variável
idade.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  547 non-null    int64
#  1   idade       547 non-null    int64
# dtypes: int64(2)
# memory usage: 8.7 KB

# %%
#estatística básica
idade.describe()
# Out:
#        id_cliente       idade
# count   547.00000  547.000000
# mean    274.00000   42.791590
# std     158.04957   15.160209
# min       1.00000   16.000000
# 25%     137.50000   30.000000
# 50%     274.00000   42.000000
# 75%     410.50000   55.000000
# max     547.00000   70.000000

# %% [markdown]
# Analisando Dados Ausentes

# %%
#Verificando valores ausentes/nulos na base
estados.isna().sum()
# Out:
# id_estado       0
# estado          0
# sigla_estado    0
# pais            2
# dtype: int64

# %%
clientes.isna().sum()
# Out:
# id_cliente    0
# peso          5
# colesterol    0
# genero        0
# id_estado     0
# dtype: int64

# %%
idade.isna().sum()
# Out:
# id_cliente    0
# idade         0
# dtype: int64

# %%
#verificando os registros com valores nulos
clientes.loc[clientes['peso'].isnull()]
# Out:
#      id_cliente  peso  colesterol     genero  id_estado
# 63           64   NaN         211  Masculino         12
# 101         102   NaN         230   Feminino         24
# 146         147   NaN         171  Masculino         23
# 195         196   NaN         143   Feminino         15
# 215         216   NaN         180  Masculino         13

# %% [markdown]
# Identificamos 5 valores ausentes na base de dados de clientes. Para esse caso, temos 3 opções para tratamento de dados numéricos:
# 1. Eliminação dos registros
# 2. Média dos pesos dos clientes: Realiza a média dos pesos OBS: A média é fortemente influenciada pela presença de valores extremos;
# 3. Mediana dos pesos dos clientes. Realiza a mediana dos pesos (medida que pega i vakir central dos dados)

# %% [markdown]
# Eliminando Dados Ausentes (exemplo didático, anulado na sequência do exercício)

# %%
#Dados Ausentes
clientes.dropna(subset=['peso'], inplace=True) # para eliminar o registro. Inplace= True significa que quer alterar os dadso naquele dataframe

# %%
clientes.isna().sum()
# Out:
# id_cliente    0
# peso          0
# colesterol    0
# genero        0
# id_estado     0
# dtype: int64

# %%
clientes.count() #os dados ausentes foram eliminados, por isso o count é menor agora.
# Out:
# id_cliente    542
# peso          542
# colesterol    542
# genero        542
# id_estado     542
# dtype: int64

# %% [markdown]
# Alterando os Dados por outras medidas (precisei rodar novamente a base de dados original, em "colentando dados")

# %%
clientes.describe()
# Out:
#        id_cliente        peso  colesterol   id_estado
# count   547.00000  542.000000  547.000000  547.000000
# mean    274.00000  143.440959  170.433272   13.833638
# std     158.04957   30.836868   39.147189    7.593117
# min       1.00000   95.000000  102.000000    1.000000
# 25%     137.50000  116.000000  136.000000    7.000000
# 50%     274.00000  140.000000  169.000000   13.000000
# 75%     410.50000  171.000000  208.000000   20.000000
# max     547.00000  203.000000  235.000000   27.000000

# %%
#Realizando a média e mediana da variável peso
media = clientes.peso.mean()
mediana = clientes.peso.median()

# %%
#verificando valores
print(f"O valor da média dos pesos é:{media}\nO valor da mediana é {mediana}")
# Out:
# O valor da média dos pesos é:143.4409594095941
# O valor da mediana é 140.0

# %%
#Fazendo arrendodamento da variável média
round(media,2)
# Out:
# 143.44

# %%
#preencher valores ausentes pela média
clientes.peso.fillna(round(media,2), inplace=True)

# %%
#Verifica se existe algum valor ausente
clientes.isna().sum()
# Out:
# id_cliente    0
# peso          0
# colesterol    0
# genero        0
# id_estado     0
# dtype: int64

# %%
clientes.count()
# Out:
# id_cliente    547
# peso          547
# colesterol    547
# genero        547
# id_estado     547
# dtype: int64

# %% [markdown]
# Substituindo Variável Categórica: Quando tempos uma variável do tipo categórica, uma abordagem é substituir o valor ausente pela variável mais frequente encontrada no conjunto de dados.

# %%
print(estados.pais.value_counts())
# Out:
# Brasil    25
# Name: pais, dtype: int64

# %%
estados.pais.fillna('Brasil', inplace=True)

# %%
estados.isna().sum()
# Out:
# id_estado       0
# estado          0
# sigla_estado    0
# pais            0
# dtype: int64

# %% [markdown]
# Analisando Distribuição dos Dados

# %%
import matplotlib.pyplot as plt

# %%
clientes.hist(column='peso', figsize=(15,7))
plt.show()

# %%
clientes.hist(column='peso', figsize=(15,7), bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f77cf115150>]],
#       dtype=object)

# %%
clientes.hist(column='colesterol', figsize=(15,7), bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f77ce5b7650>]],
#       dtype=object)

# %%
#Criando um identificador para a variável gênero
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
clientes['genero_number'] = LE.fit_transform(clientes['genero']) #rodei sem querer uma coluna "genero numeber" incorretamente e não sei apagar.

# %%
clientes
# Out:
#      id_cliente   peso  colesterol     genero  id_estado  genero_numeber  \
# 0             1  102.0         111  Masculino         23               1
# 1             2  115.0         135  Masculino          7               1
# 2             3  115.0         136  Masculino          4               1
# 3             4  140.0         167   Feminino         24               0
# 4             5  130.0         158  Masculino         26               1
# ..          ...    ...         ...        ...        ...             ...
# 542         543  172.0         207  Masculino         22               1
# 543         544  129.0         157  Masculino          1               1
# 544         545  107.0         115  Masculino          6               1
# 545         546  117.0         147  Masculino         20               1
# 546         547  148.0         176  Masculino          8               1
#
#      genero_number
# 0                1
# 1                1
# 2                1
# ...

# %%
clientes.hist(column='genero_number', figsize=(15,7), bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f77c2360590>]],
#       dtype=object)

# %% [markdown]
# Junções entre os dados coletados: Nessa etapa vamos realizar o merge entre os dados que realizamos a coleta

# %%
estados[:7]
# Out:
#    id_estado            estado sigla_estado    pais
# 0          1              Acre           ac  Brasil
# 1          2           Alagoas           al  Brasil
# 2          3             Amapá           ap  Brasil
# 3          4          Amazonas           am  Brasil
# 4          5             Bahia           ba  Brasil
# 5          6             Ceará           ce  Brasil
# 6          7  Distrito Federal           df  Brasil

# %%
clientes[:5]
# Out:
#    id_cliente   peso  colesterol     genero  id_estado  genero_numeber  \
# 0           1  102.0         111  Masculino         23               1
# 1           2  115.0         135  Masculino          7               1
# 2           3  115.0         136  Masculino          4               1
# 3           4  140.0         167   Feminino         24               0
# 4           5  130.0         158  Masculino         26               1
#
#    genero_number
# 0              1
# 1              1
# 2              1
# 3              0
# 4              1

# %%
clientes_estados = pd.merge(clientes, estados, on='id_estado')
clientes_estados.sort_values('id_cliente')
# Out:
#      id_cliente   peso  colesterol     genero  id_estado  genero_numeber  \
# 0             1  102.0         111  Masculino         23               1
# 18            2  115.0         135  Masculino          7               1
# 40            3  115.0         136  Masculino          4               1
# 65            4  140.0         167   Feminino         24               0
# 87            5  130.0         158  Masculino         26               1
# ..          ...    ...         ...        ...        ...             ...
# 443         543  172.0         207  Masculino         22               1
# 478         544  129.0         157  Masculino          1               1
# 178         545  107.0         115  Masculino          6               1
# 396         546  117.0         147  Masculino         20               1
# 123         547  148.0         176  Masculino          8               1
#
#      genero_number               estado sigla_estado    pais
# ...

# %%
#realiza junção entre Clientes e Estados
base_completa = pd.merge(clientes_estados, idade, on='id_cliente').sort_values('id_cliente')

# %%
base_completa
# Out:
#      id_cliente   peso  colesterol     genero  id_estado  genero_numeber  \
# 0             1  102.0         111  Masculino         23               1
# 18            2  115.0         135  Masculino          7               1
# 40            3  115.0         136  Masculino          4               1
# 65            4  140.0         167   Feminino         24               0
# 87            5  130.0         158  Masculino         26               1
# ..          ...    ...         ...        ...        ...             ...
# 443         543  172.0         207  Masculino         22               1
# 478         544  129.0         157  Masculino          1               1
# 178         545  107.0         115  Masculino          6               1
# 396         546  117.0         147  Masculino         20               1
# 123         547  148.0         176  Masculino          8               1
#
#      genero_number               estado sigla_estado    pais  idade
# ...

# %%
base_completa.reset_index(drop=True)
# Out:
#      id_cliente   peso  colesterol     genero  id_estado  genero_numeber  \
# 0             1  102.0         111  Masculino         23               1
# 1             2  115.0         135  Masculino          7               1
# 2             3  115.0         136  Masculino          4               1
# 3             4  140.0         167   Feminino         24               0
# 4             5  130.0         158  Masculino         26               1
# ..          ...    ...         ...        ...        ...             ...
# 542         543  172.0         207  Masculino         22               1
# 543         544  129.0         157  Masculino          1               1
# 544         545  107.0         115  Masculino          6               1
# 545         546  117.0         147  Masculino         20               1
# 546         547  148.0         176  Masculino          8               1
#
#      genero_number               estado sigla_estado    pais  idade
# ...

# %% [markdown]
# Organizando a Base de Dados: Podemos alterar, renomear, etc.

# %%
#Removendo a coluna que criei acidentalmente. Usei esse site https://www.alura.com.br/artigos/como-remover-linhas-e-colunas-no-pandas?gclid=Cj0KCQjwmdGYBhDRARIsABmSEeO65Nq48dA6RN7mJABB5MfTF33Id42d5H8irWBu13O6XDE2BELNcXEaAn5zEALw_wcB
base_completa.drop(columns=['genero_numeber'])
base_completa = base_completa.drop(columns=['genero_numeber'])

#Alterando nome das colunas
base_completa.rename(columns={'id_cliente': 'cod_cliente', 'genero_number':'cod_genero'}, inplace = True)

#print
base_completa
# Out:
#      cod_cliente   peso  colesterol     genero  id_estado  cod_genero  \
# 0              1  102.0         111  Masculino         23           1
# 18             2  115.0         135  Masculino          7           1
# 40             3  115.0         136  Masculino          4           1
# 65             4  140.0         167   Feminino         24           0
# 87             5  130.0         158  Masculino         26           1
# ..           ...    ...         ...        ...        ...         ...
# 443          543  172.0         207  Masculino         22           1
# 478          544  129.0         157  Masculino          1           1
# 178          545  107.0         115  Masculino          6           1
# 396          546  117.0         147  Masculino         20           1
# 123          547  148.0         176  Masculino          8           1
#
#                   estado sigla_estado    pais  idade
# 0                Roraima           RR  Brasil     17
# ...

# %%
#Alterando as linhas da variável sigla_estado
base_completa.sigla_estado.str.upper()
# Out:
# 0      RR
# 18     DF
# 40     AM
# 65     SC
# 87     SE
#        ..
# 443    RO
# 478    AC
# 178    CE
# 396    RN
# 123    ES
# Name: sigla_estado, Length: 547, dtype: object

# %%
#inserindo alterações realizada
base_completa['sigla_estado'] = base_completa.sigla_estado.str.upper()

# %%
#print
base_completa
# Out:
#      cod_cliente   peso  colesterol     genero  id_estado  cod_genero  \
# 0              1  102.0         111  Masculino         23           1
# 18             2  115.0         135  Masculino          7           1
# 40             3  115.0         136  Masculino          4           1
# 65             4  140.0         167   Feminino         24           0
# 87             5  130.0         158  Masculino         26           1
# ..           ...    ...         ...        ...        ...         ...
# 443          543  172.0         207  Masculino         22           1
# 478          544  129.0         157  Masculino          1           1
# 178          545  107.0         115  Masculino          6           1
# 396          546  117.0         147  Masculino         20           1
# 123          547  148.0         176  Masculino          8           1
#
#                   estado sigla_estado    pais  idade
# 0                Roraima           RR  Brasil     17
# ...

# %% [markdown]
# Alterando a disposição das colunas do arquivo de dados

# %%
base_completa[['cod_cliente', 'genero', 'idade', 'peso', 'colesterol', 'id_estado', 'estado', 'sigla_estado', 'pais']].reset_index(drop=True)
# Out:
#      cod_cliente     genero  idade   peso  colesterol  id_estado  \
# 0              1  Masculino     17  102.0         111         23
# 1              2  Masculino     28  115.0         135          7
# 2              3  Masculino     62  115.0         136          4
# 3              4   Feminino     55  140.0         167         24
# 4              5  Masculino     44  130.0         158         26
# ..           ...        ...    ...    ...         ...        ...
# 542          543  Masculino     20  172.0         207         22
# 543          544  Masculino     66  129.0         157          1
# 544          545  Masculino     36  107.0         115          6
# 545          546  Masculino     57  117.0         147         20
# 546          547  Masculino     61  148.0         176          8
#
#                   estado sigla_estado    pais
# 0                Roraima           RR  Brasil
# 1       Distrito Federal           DF  Brasil
# ...

# %%
#print
base_completa
# Out:
#      cod_cliente   peso  colesterol     genero  id_estado  cod_genero  \
# 0              1  102.0         111  Masculino         23           1
# 18             2  115.0         135  Masculino          7           1
# 40             3  115.0         136  Masculino          4           1
# 65             4  140.0         167   Feminino         24           0
# 87             5  130.0         158  Masculino         26           1
# ..           ...    ...         ...        ...        ...         ...
# 443          543  172.0         207  Masculino         22           1
# 478          544  129.0         157  Masculino          1           1
# 178          545  107.0         115  Masculino          6           1
# 396          546  117.0         147  Masculino         20           1
# 123          547  148.0         176  Masculino          8           1
#
#                   estado sigla_estado    pais  idade
# 0                Roraima           RR  Brasil     17
# ...

# %% [markdown]
# # **Análise de Dados**

# %% [markdown]
# Aplicando método do cotovelo: iniciar a identificação do número de clusteres necessários para realizar o agrupamento

# %%
from sklearn.cluster import KMeans

# %%
def calcular_wcss(dados_cliente):
  wcss = []
  for k in range(1,11):
    kmeans = KMeans(n_clusters = k)
    kmeans.fit(X=dados_cliente)
    wcss.append(kmeans.inertia_)
  return wcss

# %%
dados_cliente = base_completa[['peso', 'colesterol', 'idade']]
dados_cliente.head()
# Out:
#      peso  colesterol  idade
# 0   102.0         111     17
# 18  115.0         135     28
# 40  115.0         136     62
# 65  140.0         167     55
# 87  130.0         158     44

# %%
wcss_clientes = calcular_wcss(dados_cliente)

# %%
type(wcss_clientes) #lista
# Out:
# list

# %%
#visualizando os dados obtidos do wcss
for i in range(len(wcss_clientes)):
  print(f'O cluster {i} possui valor de WCSS de: {wcss_clientes[i]}')
# Out:
# O cluster 0 possui valor de WCSS de: 1476678.1664643502
# O cluster 1 possui valor de WCSS de: 457953.6064800842
# O cluster 2 possui valor de WCSS de: 268077.2887419374
# O cluster 3 possui valor de WCSS de: 208925.99010566415
# O cluster 4 possui valor de WCSS de: 180745.81195665107
# O cluster 5 possui valor de WCSS de: 153520.35010727582
# O cluster 6 possui valor de WCSS de: 131638.60097341522
# O cluster 7 possui valor de WCSS de: 110847.06311309017
# O cluster 8 possui valor de WCSS de: 95534.77717313232
# O cluster 9 possui valor de WCSS de: 84994.42108182982

# %% [markdown]
# Visualizando o Gráfico do Cotovelo

# %%
import plotly.express as px #criação de gráficos dinamicos
import plotly. offline as py 
import plotly.graph_objects as go #para criação e concatenização de gráfico

# %%
grafico_wcss = px.line( x=range(1,11),
                        y=wcss_clientes
                        )
fig = go.Figure(grafico_wcss)

fig.update_layout(title='Calculando o WCSS',
                  xaxis_title= 'Número de clusters',
                  yaxis_title= 'Valor do WCss',
                  template= 'plotly_white'
                  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
kmeans_clientes = KMeans(n_clusters=3, random_state=0)
base_completa['cluster'] = kmeans_clientes.fit_predict(dados_cliente)

# %%
base_completa
# Out:
#      cod_cliente   peso  colesterol     genero  id_estado  cod_genero  \
# 0              1  102.0         111  Masculino         23           1
# 18             2  115.0         135  Masculino          7           1
# 40             3  115.0         136  Masculino          4           1
# 65             4  140.0         167   Feminino         24           0
# 87             5  130.0         158  Masculino         26           1
# ..           ...    ...         ...        ...        ...         ...
# 443          543  172.0         207  Masculino         22           1
# 478          544  129.0         157  Masculino          1           1
# 178          545  107.0         115  Masculino          6           1
# 396          546  117.0         147  Masculino         20           1
# 123          547  148.0         176  Masculino          8           1
#
#                   estado sigla_estado    pais  idade  cluster
# 0                Roraima           RR  Brasil     17        1
# ...

# %% [markdown]
# Calcula os centroides de cada cluster

# %%
centroides_clusters = kmeans_clientes.cluster_centers_
centroides_clusters
# Out:
# array([[181.96141176, 217.07647059,  42.69411765],
#        [110.25      , 125.62765957,  43.5212766 ],
#        [141.80825397, 173.04761905,  42.15343915]])

# %%
dados_cliente
# Out:
#       peso  colesterol  idade
# 0    102.0         111     17
# 18   115.0         135     28
# 40   115.0         136     62
# 65   140.0         167     55
# 87   130.0         158     44
# ..     ...         ...    ...
# 443  172.0         207     20
# 478  129.0         157     66
# 178  107.0         115     36
# 396  117.0         147     57
# 123  148.0         176     61
#
# [547 rows x 3 columns]

# %%
grafico = px.scatter(x = base_completa['peso'],
                     y = base_completa['colesterol'],
                     color = base_completa['cluster'])
grafico_centroide = px.scatter(x = centroides_clusters[:,0], y = centroides_clusters[:,1], size = [7,7,7])
grafico_final_petala = go.Figure(data = grafico.data + grafico_centroide.data)
grafico_final_petala.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Visualizando e alterando o layout do gráfico

# %%
grafico = px.scatter(x = base_completa['colesterol'],
                     y = base_completa['peso'],
                     color = base_completa['cluster'])
fig = go.Figure(grafico)

fig.update_layout(title='Análise de Clusters',
                  xaxis_title= 'Colesterol',
                  yaxis_title= 'Peso',
                  )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Criando Função Para Gerar Gráfico

# %%
def plotar_grafico(x,y,xlabel, y_label):
  grafico = px.scatter(x = x,
                       y = y,
                       color= base_completa['cluster'])
  fig = go.Figure(grafico)
  
  fig.update_layout(title='Análise de Cluster',
                    xaxis_title= xlabel,
                    yaxis_title= y_label,
                    )
  fig.show()

# %%
plotar_grafico(base_completa['peso'], base_completa['colesterol'], 'peso', 'colesterol')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plotar_grafico(base_completa['idade'], base_completa['colesterol'], 'idade', 'colesterol')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Segmentando os clientes baseado na análise dos clusters (3 tipos baseado em peso e colesterol):
# 1. Alto Risco: Peso e o Colesterol Altos
# 2. Baixo Risco: Peso e Colesterol Baixos
# 3. Moderado: Peso e o Colesterol Medianos

# %%
x = 'colesterol'
y = 'peso'

plotar_grafico(base_completa[x], base_completa[y], x, y)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cluster_clientes = base_completa

# %%
#seguimentando os clientes baseados na análise dos clusters
cluster_clientes.loc[cluster_clientes['cluster']==0, 'nome_cluster'] = 'Alto Risco'
cluster_clientes.loc[cluster_clientes['cluster']==1, 'nome_cluster'] = 'Baixo Risco'
cluster_clientes.loc[cluster_clientes['cluster']==2, 'nome_cluster'] = 'Risco Moderado'

# %%
cluster_clientes
# Out:
#      cod_cliente   peso  colesterol     genero  id_estado  cod_genero  \
# 0              1  102.0         111  Masculino         23           1
# 18             2  115.0         135  Masculino          7           1
# 40             3  115.0         136  Masculino          4           1
# 65             4  140.0         167   Feminino         24           0
# 87             5  130.0         158  Masculino         26           1
# ..           ...    ...         ...        ...        ...         ...
# 443          543  172.0         207  Masculino         22           1
# 478          544  129.0         157  Masculino          1           1
# 178          545  107.0         115  Masculino          6           1
# 396          546  117.0         147  Masculino         20           1
# 123          547  148.0         176  Masculino          8           1
#
#                   estado sigla_estado    pais  idade  cluster    nome_cluster
# ...

# %% [markdown]
# Análises dos CLusteres Criados

# %%
#Verifica os valores de idade por cluster
cluster_clientes.groupby('nome_cluster')['idade'].describe()
# Out:
#                 count       mean        std   min   25%   50%    75%   max
# nome_cluster
# Alto Risco      170.0  42.694118  15.231564  16.0  31.0  43.0  55.75  69.0
# Baixo Risco     188.0  43.521277  15.009251  17.0  31.0  42.0  57.00  70.0
# Risco Moderado  189.0  42.153439  15.294024  16.0  29.0  42.0  54.00  70.0

# %%
#Verifica os valores de estado por cluster
cluster_clientes.groupby('nome_cluster')['estado'].describe()
# Out:
#                count unique                 top freq
# nome_cluster
# Alto Risco       170     27   Rio Grande do Sul   10
# Baixo Risco      188     27            Amazonas   13
# Risco Moderado   189     27  Mato Grosso do Sul   13

# %%
cluster_clientes.query('nome_cluster == "Alto Risco" & estado == "Mato Grosso"')
# Out:
#      cod_cliente   peso  colesterol     genero  id_estado  cod_genero  \
# 315          112  179.0         214  Masculino         11           1
# 316          155  167.0         204  Masculino         11           1
# 317          160  171.0         212  Masculino         11           1
# 318          168  184.0         222  Masculino         11           1
# 319          172  161.0         201   Feminino         11           0
# 320          198  173.0         211  Masculino         11           1
# 321          227  184.0         220  Masculino         11           1
# 322          248  171.0         204  Masculino         11           1
# 324          361  180.0         218   Feminino         11           0
# 328          518  172.0         210   Feminino         11           0
#
#           estado sigla_estado    pais  idade  cluster nome_cluster
# 315  Mato Grosso           MT  Brasil     66        0   Alto Risco
# ...

# %%
cluster_clientes.groupby(['nome_cluster', 'genero'])['peso'].describe()
# Out:
#                           count        mean        std     min    25%     50%  \
# nome_cluster   genero
# Alto Risco     Feminino    71.0  182.823099  11.441636  143.44  178.0  185.00
#                Masculino   99.0  181.343434  11.701353  159.00  172.0  180.00
# Baixo Risco    Feminino    84.0  111.166667   7.829252   96.00  107.0  112.00
#                Masculino  104.0  109.509615   8.139554   95.00  103.0  108.00
# Risco Moderado Feminino   111.0  142.193153  10.351079  124.00  134.0  141.00
#                Masculino   78.0  141.260513  10.220661  124.00  132.0  143.72
#
#                              75%    max
# nome_cluster   genero
# Alto Risco     Feminino   191.00  203.0
#                Masculino  188.00  203.0
# Baixo Risco    Feminino   117.00  126.0
#                Masculino  117.00  126.0
# Risco Moderado Feminino   152.50  159.0
#                Masculino  150.75  157.0

# %% [markdown]
# # Exportando Dados

# %%
cluster_clientes.to_csv('classificação_clientes.csv', sep = ';', encoding='latin1')
